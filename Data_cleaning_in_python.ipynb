# %% [markdown]
# <a href="https://colab.research.google.com/github/michaelnonso/data-analytics/blob/main/Data_cleaning_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import libraries

# %% [markdown]
# Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Generating sample data

# %%
np.random.seed(42)
data = {
    'Age': np.random.randint(18, 65, 100),
    'Income': np.random.normal(50000, 15000, 100),
    'Score': np.random.uniform(0, 100, 100)
}
df = pd.DataFrame(data)

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of     Age        Income      Score
# 0    56  59544.576625  17.495493
# 1    46  36399.189971  98.216834
# 2    32  57140.638811  51.663589
# 3    60  69554.919026  26.082917
# 4    25  53173.805185  99.625370
# ..  ...           ...        ...
# 95   24  63099.754536  88.661715
# 96   26  53084.752010   2.761677
# 97   41  28347.749725  57.886490
# 98   18  34584.337039  43.847412
# 99   61  61118.609526  67.202614
#
# [100 rows x 3 columns]>

# %% [markdown]
# Visualizing Data Distributions

# %% [markdown]
# Set style

# %%
sns.set(style="whitegrid")

# %% [markdown]
# Visualize age distribution

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Age', kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Visualize income distribution

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Income', kde=True)
plt.title('Income Distribution')
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Visualize score distribution

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Score', kde=True)
plt.title('Score Distribution')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Plotting and Visualizing Outliers
# Visualize outliers using box plots

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['Age', 'Income', 'Score']])
plt.title('Outliers')
plt.xlabel('Variable')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# Visualizing Missing Values:
# # Introduce missing values

# %%
df['Age'].iloc[5:15] = np.nan
df['Income'].iloc[20:30] = np.nan
df['Score'].iloc[40:50] = np.nan
# Out:
# <ipython-input-9-2cbcb63c13f0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].iloc[5:15] = np.nan

# %%
print (df.isnull().sum())
# Out:
# Age       10
# Income    10
# Score     10
# dtype: int64

# %% [markdown]
# Visualize missing values using a heatmap

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cmap='viridis', cbar=False)
plt.title('Missing Values')
plt.show()

# %%
print (df.iloc[28,:])
# Out:
# Age       42.000000
# Income          NaN
# Score     17.592525
# Name: 28, dtype: float64
